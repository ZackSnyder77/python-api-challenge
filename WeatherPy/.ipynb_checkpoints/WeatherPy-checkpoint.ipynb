# %% [markdown]
# ### WeatherPy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import json
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ### Generate List of Cities

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 577

# %% [markdown]
# ### Start API Calls

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"

# %%
record_count = 0

params = {
    "appid": weather_api_key,
    "units": "Imperial",
    "q": ""
}

data = {
    "City": [],
    "Cloudiness": [],
    "Country": [],
    "Date": [],
    "Humidity": [],
    "Lat": [],
    "Lng": [],
    "Max Temp": [],
    "Wind Speed": [],
}

print("Beginning Data Retrieval")
print("--------------------------")



for city in cities:
    params["q"] = city
    response = requests.get(url, params)
#     print(response.url)
    response_json = response.json()
    record_count = record_count + 1

    try:
        data["City"].append(response_json["name"])
        data["Cloudiness"].append(response_json["clouds"]["all"])
        data["Country"].append(response_json["sys"]["country"])
        data["Date"].append(response_json["dt"])
        data["Humidity"].append(response_json["main"]["humidity"])
        data["Lat"].append(response_json["coord"]["lat"])
        data["Lng"].append(response_json["coord"]["lon"])
        data["Max Temp"].append(response_json["main"]["temp_max"])
        data["Wind Speed"].append(response_json["wind"]["speed"])
        print(f"Processing Record {record_count} | {city}")
    except:
        # Append null values
        print("City not found.  Skipping...")
        pass
print("--------------------------")
print("Data Retrieval Complete")
print("--------------------------")
# Out:
# Beginning Data Retrieval
# --------------------------
# Processing Record 1 | pevek
# Processing Record 2 | hermanus
# Processing Record 3 | zhigansk
# Processing Record 4 | lorengau
# Processing Record 5 | albany
# Processing Record 6 | vila velha
# Processing Record 7 | new norfolk
# Processing Record 8 | caravelas
# Processing Record 9 | bluff
# Processing Record 10 | bengkulu
# Processing Record 11 | ribeira grande
# Processing Record 12 | guanare
# Processing Record 13 | east london
# Processing Record 14 | mataura
# Processing Record 15 | mahebourg
# Processing Record 16 | upernavik
# Processing Record 17 | esperance
# Processing Record 18 | rikitea
# Processing Record 19 | tautira
# Processing Record 20 | faya
# Processing Record 21 | dafeng
# Processing Record 22 | tiksi
# Processing Record 23 | ocos
# Processing Record 24 | nioro
# Processing Record 25 | jipapad
# Processing Record 26 | sobolevo
# Processing Record 27 | bethel
# Processing Record 28 | berlevag
# Processing Record 29 | leningradskiy
# Processing Record 30 | qaanaaq
# Processing Record 31 | carnarvon
# Processing Record 32 | port alfred
# Processing Record 33 | tasiilaq
# Processing Record 34 | aksu
# Processing Record 35 | torbay
# City not found.  Skipping...
# Processing Record 37 | khatanga
# Processing Record 38 | sabha
# Processing Record 39 | bredasdorp
# Processing Record 40 | vestmannaeyjar
# Processing Record 41 | saint-philippe
# Processing Record 42 | port-cartier
# Processing Record 43 | gimli
# Processing Record 44 | coracora
# Processing Record 45 | ushuaia
# Processing Record 46 | huarmey
# Processing Record 47 | avarua
# Processing Record 48 | moose factory
# Processing Record 49 | cherskiy
# Processing Record 50 | kapaa
# Processing Record 51 | leshukonskoye
# Processing Record 52 | butaritari
# Processing Record 53 | klaksvik
# Processing Record 54 | saint-augustin
# Processing Record 55 | mar del plata
# Processing Record 56 | ketchikan
# Processing Record 57 | whitehorse
# Processing Record 58 | santa cruz
# Processing Record 59 | quba
# Processing Record 60 | busselton
# Processing Record 61 | flinders
# Processing Record 62 | faanui
# Processing Record 63 | kahului
# Processing Record 64 | dikson
# Processing Record 65 | pahrump
# Processing Record 66 | peddapalli
# Processing Record 67 | castro
# Processing Record 68 | punta arenas
# Processing Record 69 | half moon bay
# Processing Record 70 | sangmelima
# Processing Record 71 | sinnamary
# Processing Record 72 | port-gentil
# Processing Record 73 | pisco
# Processing Record 74 | dukat
# Processing Record 75 | jamestown
# Processing Record 76 | raudeberg
# Processing Record 77 | vila franca do campo
# City not found.  Skipping...
# City not found.  Skipping...
# Processing Record 80 | sitka
# Processing Record 81 | hobart
# City not found.  Skipping...
# Processing Record 83 | vallenar
# Processing Record 84 | sainte-marie
# Processing Record 85 | salalah
# Processing Record 86 | cape town
# Processing Record 87 | atuona
# Processing Record 88 | lisakovsk
# Processing Record 89 | namatanai
# Processing Record 90 | kyren
# Processing Record 91 | fort nelson
# Processing Record 92 | nikolskoye
# Processing Record 93 | savelugu
# Processing Record 94 | flin flon
# Processing Record 95 | wawa
# Processing Record 96 | richards bay
# Processing Record 97 | port hardy
# Processing Record 98 | weihai
# City not found.  Skipping...
# Processing Record 100 | xining
# Processing Record 101 | ossora
# Processing Record 102 | hofn
# Processing Record 103 | methoni
# Processing Record 104 | sulangan
# Processing Record 105 | avera
# Processing Record 106 | ponta do sol
# Processing Record 107 | luau
# City not found.  Skipping...
# City not found.  Skipping...
# Processing Record 110 | olafsvik
# Processing Record 111 | henties bay
# Processing Record 112 | guantanamo
# City not found.  Skipping...
# Processing Record 114 | brae
# Processing Record 115 | hattiesburg
# Processing Record 116 | kodiak
# Processing Record 117 | barrow
# Processing Record 118 | manicore
# Processing Record 119 | puerto narino
# Processing Record 120 | ambilobe
# Processing Record 121 | gat
# Processing Record 122 | arraial do cabo
# Processing Record 123 | port elizabeth
# Processing Record 124 | jumla
# City not found.  Skipping...
# Processing Record 126 | grenada
# Processing Record 127 | buala
# Processing Record 128 | iskateley
# Processing Record 129 | airai
# Processing Record 130 | colares
# Processing Record 131 | cidreira
# Processing Record 132 | antalaha
# Processing Record 133 | aykhal
# Processing Record 134 | aksarka
# Processing Record 135 | kharabali
# Processing Record 136 | mogadishu
# Processing Record 137 | chuy
# Processing Record 138 | mananjary
# Processing Record 139 | norman wells
# Processing Record 140 | skjervoy
# City not found.  Skipping...
# Processing Record 142 | mbaiki
# Processing Record 143 | teahupoo
# Processing Record 144 | shetpe
# Processing Record 145 | tuktoyaktuk
# Processing Record 146 | eureka
# Processing Record 147 | yellowknife
# Processing Record 148 | glendive
# Processing Record 149 | ilulissat
# Processing Record 150 | ahuimanu
# Processing Record 151 | pimenta bueno
# Processing Record 152 | birjand
# Processing Record 153 | saldanha
# Processing Record 154 | victoria
# Processing Record 155 | vaini
# Processing Record 156 | dunedin
# Processing Record 157 | saint-francois
# Processing Record 158 | broome
# Processing Record 159 | kubinka
# Processing Record 160 | bathsheba
# Processing Record 161 | puerto ayora
# Processing Record 162 | aripuana
# Processing Record 163 | comodoro rivadavia
# Processing Record 164 | plettenberg bay
# Processing Record 165 | itarema
# Processing Record 166 | husavik
# Processing Record 167 | komsomolskiy
# Processing Record 168 | oktyabrskiy
# Processing Record 169 | okha
# Processing Record 170 | chengalpattu
# Processing Record 171 | gushikawa
# Processing Record 172 | dire
# Processing Record 173 | salihorsk
# Processing Record 174 | sergeyevka
# Processing Record 175 | lebu
# Processing Record 176 | bharatpur
# Processing Record 177 | yangambi
# Processing Record 178 | thompson
# Processing Record 179 | beringovskiy
# City not found.  Skipping...
# Processing Record 181 | baruun-urt
# Processing Record 182 | abha
# Processing Record 183 | santa isabel do rio negro
# Processing Record 184 | karimpur
# Processing Record 185 | sorland
# Processing Record 186 | gravdal
# Processing Record 187 | hohhot
# Processing Record 188 | bobo dioulasso
# City not found.  Skipping...
# Processing Record 190 | nieuw amsterdam
# Processing Record 191 | plyussa
# Processing Record 192 | qaqortoq
# Processing Record 193 | caarapo
# Processing Record 194 | effingham
# Processing Record 195 | bubaque
# Processing Record 196 | chokurdakh
# Processing Record 197 | fortuna
# Processing Record 198 | mokhotlong
# Processing Record 199 | longyearbyen
# Processing Record 200 | kaitangata
# Processing Record 201 | ugoofaaru
# Processing Record 202 | kaeo
# Processing Record 203 | malindi
# Processing Record 204 | arlit
# Processing Record 205 | ucluelet
# Processing Record 206 | killybegs
# Processing Record 207 | yar-sale
# Processing Record 208 | hilo
# Processing Record 209 | marquetalia
# Processing Record 210 | provideniya
# Processing Record 211 | vendome
# Processing Record 212 | fereydun kenar
# Processing Record 213 | guerrero negro
# Processing Record 214 | sabalgarh
# City not found.  Skipping...
# Processing Record 216 | mount gambier
# Processing Record 217 | san patricio
# Processing Record 218 | kudahuvadhoo
# Processing Record 219 | yishui
# Processing Record 220 | bodden town
# Processing Record 221 | taoudenni
# Processing Record 222 | ionia
# Processing Record 223 | rovnoye
# City not found.  Skipping...
# Processing Record 225 | pala
# Processing Record 226 | abu samrah
# Processing Record 227 | manta
# Processing Record 228 | rocha
# Processing Record 229 | port blair
# Processing Record 230 | santa luzia
# Processing Record 231 | geraldton
# Processing Record 232 | charagua
# Processing Record 233 | hambantota
# Processing Record 234 | yagoua
# Processing Record 235 | dutlwe
# Processing Record 236 | georgetown
# City not found.  Skipping...
# Processing Record 238 | dwarka
# City not found.  Skipping...
# City not found.  Skipping...
# Processing Record 241 | shuyskoye
# Processing Record 242 | alofi
# Processing Record 243 | bay roberts
# City not found.  Skipping...
# Processing Record 245 | poya
# Processing Record 246 | sola
# Processing Record 247 | bambous virieux
# Processing Record 248 | batagay-alyta
# Processing Record 249 | nanortalik
# Processing Record 250 | cayenne
# City not found.  Skipping...
# Processing Record 252 | yulara
# Processing Record 253 | luderitz
# City not found.  Skipping...
# Processing Record 255 | san juan de los morros
# Processing Record 256 | mandali
# Processing Record 257 | sura
# Processing Record 258 | hobyo
# Processing Record 259 | atasu
# Processing Record 260 | severo-kurilsk
# Processing Record 261 | hasaki
# Processing Record 262 | iacu
# Processing Record 263 | tra vinh
# Processing Record 264 | belaya gora
# Processing Record 265 | salvador
# Processing Record 266 | southern pines
# Processing Record 267 | muros
# Processing Record 268 | codrington
# Processing Record 269 | ayan
# Processing Record 270 | okhotsk
# Processing Record 271 | kismayo
# Processing Record 272 | la roche-sur-yon
# Processing Record 273 | kurilsk
# Processing Record 274 | vao
# City not found.  Skipping...
# Processing Record 276 | weiser
# Processing Record 277 | atherton
# Processing Record 278 | hauterive
# Processing Record 279 | nouadhibou
# Processing Record 280 | fairlie
# Processing Record 281 | solnechnyy
# Processing Record 282 | pangnirtung
# Processing Record 283 | ulladulla
# Processing Record 284 | saskylakh
# Processing Record 285 | nome
# Processing Record 286 | iqaluit
# Processing Record 287 | christchurch
# Processing Record 288 | kawalu
# Processing Record 289 | soubre
# Processing Record 290 | codo
# Processing Record 291 | yumen
# Processing Record 292 | bonavista
# Processing Record 293 | dyersburg
# Processing Record 294 | ahipara
# Processing Record 295 | marawi
# Processing Record 296 | mujiayingzi
# Processing Record 297 | sibolga
# Processing Record 298 | oromocto
# Processing Record 299 | donskoye
# Processing Record 300 | kirakira
# Processing Record 301 | tongliao
# Processing Record 302 | fairbanks
# Processing Record 303 | ulaangom
# Processing Record 304 | buhovo
# Processing Record 305 | krasnoselkup
# Processing Record 306 | rauma
# Processing Record 307 | sosnovo-ozerskoye
# Processing Record 308 | lasa
# Processing Record 309 | mbinga
# Processing Record 310 | shirokiy
# Processing Record 311 | borogontsy
# Processing Record 312 | necochea
# Processing Record 313 | grindavik
# Processing Record 314 | san ramon
# Processing Record 315 | namibe
# Processing Record 316 | bowen
# Processing Record 317 | hay river
# Processing Record 318 | nysa
# Processing Record 319 | ancud
# Processing Record 320 | kruisfontein
# Processing Record 321 | banon
# Processing Record 322 | agadez
# Processing Record 323 | sanming
# Processing Record 324 | visby
# City not found.  Skipping...
# Processing Record 326 | huangmei
# Processing Record 327 | lingao
# City not found.  Skipping...
# Processing Record 329 | sur
# Processing Record 330 | takaka
# City not found.  Skipping...
# Processing Record 332 | sao joao da barra
# Processing Record 333 | noumea
# Processing Record 334 | huzhou
# Processing Record 335 | te anau
# Processing Record 336 | rudnaya pristan
# Processing Record 337 | mangrol
# Processing Record 338 | egvekinot
# Processing Record 339 | nara
# Processing Record 340 | rodrigues alves
# Processing Record 341 | dutse
# Processing Record 342 | pendleton
# Processing Record 343 | kimbe
# Processing Record 344 | puerto leguizamo
# Processing Record 345 | esmeraldas
# Processing Record 346 | calderitas
# Processing Record 347 | abyek
# Processing Record 348 | deputatskiy
# Processing Record 349 | batemans bay
# Processing Record 350 | nabire
# Processing Record 351 | kirkwall
# Processing Record 352 | constitucion
# Processing Record 353 | turbat
# Processing Record 354 | hithadhoo
# Processing Record 355 | hede
# Processing Record 356 | haines junction
# Processing Record 357 | dhone
# Processing Record 358 | bilibino
# Processing Record 359 | north bend
# Processing Record 360 | nemuro
# Processing Record 361 | lavrentiya
# Processing Record 362 | nizhniy kuranakh
# Processing Record 363 | ashcroft
# Processing Record 364 | paamiut
# Processing Record 365 | ornskoldsvik
# Processing Record 366 | laguna
# Processing Record 367 | manavalakurichi
# Processing Record 368 | labuhan
# Processing Record 369 | payakumbuh
# Processing Record 370 | las vegas
# Processing Record 371 | kangaatsiaq
# Processing Record 372 | inuvik
# Processing Record 373 | malandag
# Processing Record 374 | mount isa
# Processing Record 375 | vestmanna
# Processing Record 376 | nantucket
# Processing Record 377 | tiznit
# Processing Record 378 | gizo
# Processing Record 379 | sambava
# Processing Record 380 | panalingaan
# Processing Record 381 | gorontalo
# Processing Record 382 | westport
# Processing Record 383 | san andres
# Processing Record 384 | villanueva de cordoba
# Processing Record 385 | vila do maio
# Processing Record 386 | kalmunai
# Processing Record 387 | otane
# Processing Record 388 | leh
# Processing Record 389 | mahon
# Processing Record 390 | huaicheng
# Processing Record 391 | san cristobal
# Processing Record 392 | padang
# Processing Record 393 | ingham
# Processing Record 394 | pangkalanbuun
# Processing Record 395 | cabo san lucas
# Processing Record 396 | vuktyl
# Processing Record 397 | sonoita
# City not found.  Skipping...
# Processing Record 399 | okato
# Processing Record 400 | terrace
# City not found.  Skipping...
# Processing Record 402 | winnemucca
# City not found.  Skipping...
# Processing Record 404 | bossangoa
# Processing Record 405 | fort pierce
# Processing Record 406 | nhulunbuy
# Processing Record 407 | ostersund
# Processing Record 408 | pascagoula
# Processing Record 409 | nenton
# Processing Record 410 | korla
# Processing Record 411 | rabo de peixe
# Processing Record 412 | quatre cocos
# Processing Record 413 | kirando
# City not found.  Skipping...
# Processing Record 415 | lata
# Processing Record 416 | saint george
# Processing Record 417 | tarpon springs
# Processing Record 418 | lagoa
# Processing Record 419 | polewali
# Processing Record 420 | churapcha
# Processing Record 421 | coihaique
# Processing Record 422 | ivanjica
# Processing Record 423 | kalaleh
# Processing Record 424 | shache
# Processing Record 425 | tilichiki
# Processing Record 426 | eston
# Processing Record 427 | tuatapere
# Processing Record 428 | malumfashi
# Processing Record 429 | ambon
# Processing Record 430 | margate
# Processing Record 431 | mindyak
# Processing Record 432 | santa maria
# Processing Record 433 | roma
# Processing Record 434 | rimini
# Processing Record 435 | slave lake
# Processing Record 436 | tianpeng
# Processing Record 437 | kamenka
# City not found.  Skipping...
# Processing Record 439 | akureyri
# Processing Record 440 | jeremoabo
# Processing Record 441 | tromso
# Processing Record 442 | aborlan
# Processing Record 443 | alugan
# Processing Record 444 | mehamn
# Processing Record 445 | goderich
# Processing Record 446 | jieshi
# Processing Record 447 | ust-nera
# Processing Record 448 | iquique
# Processing Record 449 | fukue
# Processing Record 450 | hovd
# Processing Record 451 | peru
# Processing Record 452 | pochutla
# Processing Record 453 | amapa
# Processing Record 454 | anadyr
# Processing Record 455 | mandalgovi
# Processing Record 456 | koshurnikovo
# City not found.  Skipping...
# Processing Record 458 | barcelos
# Processing Record 459 | evensk
# Processing Record 460 | sandwich
# Processing Record 461 | trairi
# Processing Record 462 | kopervik
# Processing Record 463 | russell
# Processing Record 464 | marfino
# Processing Record 465 | kralendijk
# Processing Record 466 | pirgos
# Processing Record 467 | lovozero
# Processing Record 468 | praia
# Processing Record 469 | zhaoyuan
# Processing Record 470 | katsuura
# Processing Record 471 | maxixe
# Processing Record 472 | teguise
# Processing Record 473 | kenai
# Processing Record 474 | beyneu
# Processing Record 475 | morro da fumaca
# Processing Record 476 | zarinsk
# Processing Record 477 | bambanglipuro
# Processing Record 478 | turayf
# City not found.  Skipping...
# Processing Record 480 | bundaberg
# Processing Record 481 | caravaggio
# Processing Record 482 | clyde river
# Processing Record 483 | atenas de san cristobal
# Processing Record 484 | puerto madryn
# Processing Record 485 | okakarara
# Processing Record 486 | ambulu
# Processing Record 487 | tirano
# Processing Record 488 | gazanjyk
# Processing Record 489 | preobrazheniye
# Processing Record 490 | hamilton
# City not found.  Skipping...
# Processing Record 492 | rio pardo de minas
# Processing Record 493 | oum hadjer
# City not found.  Skipping...
# Processing Record 495 | ermua
# Processing Record 496 | yakeshi
# Processing Record 497 | neuquen
# Processing Record 498 | tomatlan
# Processing Record 499 | benalla
# Processing Record 500 | yuzhnyy
# Processing Record 501 | golden
# Processing Record 502 | yulin
# Processing Record 503 | carutapera
# Processing Record 504 | santo antonio do sudoeste
# Processing Record 505 | semporna
# Processing Record 506 | zhangye
# Processing Record 507 | sungaipenuh
# Processing Record 508 | key west
# Processing Record 509 | alta floresta
# Processing Record 510 | yerbogachen
# City not found.  Skipping...
# City not found.  Skipping...
# Processing Record 513 | meulaboh
# Processing Record 514 | lucea
# Processing Record 515 | beaverlodge
# Processing Record 516 | birin
# Processing Record 517 | aklavik
# Processing Record 518 | houma
# Processing Record 519 | makungu
# City not found.  Skipping...
# Processing Record 521 | harbour breton
# City not found.  Skipping...
# Processing Record 523 | price
# Processing Record 524 | karratha
# Processing Record 525 | omsukchan
# Processing Record 526 | sapulpa
# City not found.  Skipping...
# Processing Record 528 | wajima
# Processing Record 529 | jonkoping
# Processing Record 530 | sinazongwe
# Processing Record 531 | kirov
# Processing Record 532 | medvedka
# Processing Record 533 | gueret
# Processing Record 534 | viedma
# Processing Record 535 | khrebtovaya
# Processing Record 536 | dabakala
# Processing Record 537 | tulum
# Processing Record 538 | teya
# Processing Record 539 | gambissara
# Processing Record 540 | kudymkar
# Processing Record 541 | aden
# Processing Record 542 | larsnes
# Processing Record 543 | dubuque
# Processing Record 544 | igarka
# Processing Record 545 | barberino di mugello
# Processing Record 546 | ericeira
# City not found.  Skipping...
# Processing Record 548 | santa rosa
# Processing Record 549 | cerrito
# Processing Record 550 | aleksandrovsk-sakhalinskiy
# Processing Record 551 | kara-tyube
# Processing Record 552 | sept-iles
# Processing Record 553 | northam
# Processing Record 554 | shellbrook
# Processing Record 555 | banes
# Processing Record 556 | maningrida
# Processing Record 557 | karak
# Processing Record 558 | asau
# Processing Record 559 | walvis bay
# Processing Record 560 | bang saphan
# Processing Record 561 | store heddinge
# Processing Record 562 | samarai
# Processing Record 563 | port augusta
# Processing Record 564 | adrar
# Processing Record 565 | kemijarvi
# City not found.  Skipping...
# Processing Record 567 | bud
# Processing Record 568 | mokhsogollokh
# Processing Record 569 | waddan
# Processing Record 570 | santos reyes nopala
# City not found.  Skipping...
# City not found.  Skipping...
# Processing Record 573 | hornepayne
# Processing Record 574 | loandjili
# Processing Record 575 | mugur-aksy
# Processing Record 576 | moramanga
# Processing Record 577 | wynyard
# --------------------------
# Data Retrieval Complete
# --------------------------

# %%
df = pd.DataFrame(data)
df.head()
# Out:
#        City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     Pevek          54      RU  1584217290        76  69.70  170.31
# 1  Hermanus          53      ZA  1584217291        88 -34.42   19.23
# 2  Zhigansk         100      RU  1584217291        95  66.77  123.37
# 3  Lorengau         100      PG  1584217291        78  -2.02  147.27
# 4    Albany          75      US  1584216776        42  42.60  -73.97
#
#    Max Temp  Wind Speed
# 0    -10.89        9.19
# 1     64.99       13.40
# 2     -5.85       21.77
# 3     83.79       12.21
# 4     46.00       23.04

# %%
df.count()
# Out:
# City          535
# Cloudiness    535
# Country       535
# Date          535
# Humidity      535
# Lat           535
# Lng           535
# Max Temp      535
# Wind Speed    535
# dtype: int64

# %%
df.to_csv(output_data_file,index= False)

# %%
weather_data = df.set_index('City')
weather_data.head()
# Out:
#           Cloudiness Country        Date  Humidity    Lat     Lng  Max Temp  \
# City
# Pevek             54      RU  1584217290        76  69.70  170.31    -10.89
# Hermanus          53      ZA  1584217291        88 -34.42   19.23     64.99
# Zhigansk         100      RU  1584217291        95  66.77  123.37     -5.85
# Lorengau         100      PG  1584217291        78  -2.02  147.27     83.79
# Albany            75      US  1584216776        42  42.60  -73.97     46.00
#
#           Wind Speed
# City
# Pevek           9.19
# Hermanus       13.40
# Zhigansk       21.77
# Lorengau       12.21
# Albany         23.04

# %% [markdown]
# ### Plotting the Data

# %% [markdown]
# ##### Latitude vs. Temperature Plot
# ###### Observation 1:
# The Max Temperature rises the closer you get to the Equator (0 Latitude).  As you move away from the Equator, the Max Temperature decreases.

# %%
# Create a scatter plot which compares MPG to horsepower
weather_data.plot(kind="scatter", x="Lat", y="Max Temp", grid=True, figsize=(8,8),alpha=0.9,marker="o",edgecolors="black",
              title="City Latitude Vs. Max Temperature (3/14/2020)")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.savefig("output_data/Lat_vs_Temp.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Create a scatter plot which compares MPG to horsepower
weather_data.plot(kind="scatter", x="Lat", y="Humidity", grid=True, figsize=(8,8),alpha=0.9,marker="o",edgecolors="black",
              title="City Latitude Vs. Humidity (3/14/2020)")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.savefig("output_data/Lat_vs_Humidity.png")
plt.show()

# %% [markdown]
# ##### Latitude vs. Cloudiness Plot
# ###### Observation 2:
# There appears to be no correlation between Latitude and Humidity.  I believe Humidity is more dependant on the local vegetation as well as the local rainfail amount.

# %%
# Create a scatter plot which compares MPG to horsepower
weather_data.plot(kind="scatter", x="Lat", y="Cloudiness", grid=True, figsize=(8,8),alpha=0.9,marker="o",edgecolors="black",
              title="City Latitude Vs. Cloudiness (3/14/2020)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.savefig("output_data/Lat_vs_Cloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot
# ###### Observation 3:
# Below 40 degrees of Latitude, there appears to be no correlation between Latitude and Wind Speed.  However, at 40 degrees of Latitude and above there appears to be an overall slight upward trend un Wind Speed.

# %%
# Create a scatter plot which compares MPG to horsepower
weather_data.plot(kind="scatter", x="Lat", y="Wind Speed", grid=True, figsize=(8,8),alpha=0.9,marker="o",edgecolors="black",
              title="City Latitude Vs. Wind Speed (3/14/2020)")
plt.ylabel("Wind Speed (mpg)")
plt.xlabel("Latitude")
plt.savefig("output_data/Lat_vs_Wind_Speed.png")
plt.show()
